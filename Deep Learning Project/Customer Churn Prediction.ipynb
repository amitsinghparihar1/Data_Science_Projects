# %% [markdown]
# # Bank Customer Churn Prediction

# %% [markdown]
# The aim of this project to analyze the bank customer's demographics and financial information which inculdes customer's age, gender. country, credit score, balance and many others to predict whether the customer will leave the bank or not.

# %% [markdown]
# # About the dataset

# %% [markdown]
# The dataset is taken from Kaggle. It contains 10000 rows and 14 columns. The objective of the dataset is to predict whether the customer will leave the bank or not, based on the customer's demographics and financial information included in the dataset.
#
# The dataset has several factors that can influence the customer to leave the bank, which are termed as independent variables. The target variable is the customer's decision to leave the bank, which is termed as dependent variable.

# %% [markdown]
# # Data Dictionary

# %% [raw]
# Column Name 	    Description
# ---------------------------------------------------------------------
# 1. RowNumber	    Row number
# 2. CustomerId	    Unique identification key for different customers
# 3. Surname	        Customer's last name
# 4. CreditScore	    Credit score of the customer
# 5. Geography	    Country of the customer
# 6. Age	            Age of the customer
# 7. Tenure	        Number of years for which the customer has been with the bank
# 8. Balance	        Bank balance of the customer
# 9. NumOfProducts	Number of bank products the customer is utilising
# 10. HasCrCard	    Binary flag for whether the customer holds a credit card with the bank or not
# 11. IsActiveMember	Binary flag for whether the customer is an active member with the bank or not
# 12. EstimatedSalary	Estimated salary of the customer in Dollars
# 13. Exited	        Binary flag 1 if the customer closed account with bank and 0 if the customer is retained

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\contents\Data_Science_Projects\Customer Churn Prediction\churn.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.set_index("RowNumber", inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,8))
sns.histplot(x="Balance", data=df, kde=True, hue="Exited")
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Balance', ylabel='Count'>

# %% [markdown]
# number of peoples with zero balance are high as compared to other

# %%
sns.kdeplot(df['CreditScore'])
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
df["Exited"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.stripplot(y="CreditScore", x="Exited", data=df, jitter=.1)
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Exited', ylabel='CreditScore'>

# %%
sns.catplot(y="Balance", x="Exited", data=df, kind="strip", col="Geography")
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x="Exited", data=df, hue="Gender", kind="count", col="Geography")
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.catplot(x="Exited", data=df, kind="count", hue="Geography")
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.histplot(x="HasCrCard", hue="Exited", data=df)
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='HasCrCard', ylabel='Count'>

# %%
sns.histplot(x="IsActiveMember", hue="Exited", data=df)
# Out:
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\amits\deeplearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='IsActiveMember', ylabel='Count'>

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.drop("Surname", axis=1, inplace=True)

# %%
df.drop("CustomerId", axis=1, inplace=True)

# %%
df.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 937.5+ KB

# %%
df=df.join(pd.get_dummies(df["Geography"], prefix='Geography'))

# %%
df=df.join(pd.get_dummies(df["Gender"], prefix='Gender'))

# %%
df.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0
#
#            Geography_France  Geography_Germany  Geography_Spain  \
# RowNumber
# 1                      True              False            False
# 2                     False              False             True
# 3                      True              False            False
# 4                      True              False            False
# 5                     False              False             True
#
#            Gender_Female  Gender_Male
# RowNumber
# 1                   True        False
# 2                   True        False
# 3                   True        False
# 4                   True        False
# 5                   True        False

# %%
df["Geography_France"] = df["Geography_France"].astype(int)
df["Geography_Germany"] = df["Geography_Germany"].astype(int)
df["Geography_Spain"] = df["Geography_Spain"].astype(int)
df["Gender_Female"] = df["Gender_Female"].astype(int)
df["Gender_Male"] = df["Gender_Male"].astype(int)

# %%
df=df.drop(columns=["Gender", "Geography"], axis=1)

# %%
corr=df.corr()
corr
# Out:
#                    CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore           1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                  -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure                0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance               0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts         0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard            -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember        0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary      -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited               -0.027094  0.285323 -0.014001  0.118533      -0.047820
# Geography_France     -0.008928 -0.039208 -0.002848 -0.231329       0.001230
# Geography_Germany     0.005538  0.046897 -0.000567  0.401110      -0.010419
# Geography_Spain       0.004780 -0.001685  0.003868 -0.134892       0.009039
# Gender_Female         0.002857  0.027544 -0.014733 -0.012087       0.021859
# Gender_Male          -0.002857 -0.027544  0.014733  0.012087      -0.021859
#
#                    HasCrCard  IsActiveMember  EstimatedSalary    Exited  \
# CreditScore        -0.005458        0.025651        -0.001384 -0.027094
# Age                -0.011721        0.085472        -0.007201  0.285323
# Tenure              0.022583       -0.028362         0.007784 -0.014001
# Balance            -0.014858       -0.010084         0.012797  0.118533
# NumOfProducts       0.003183        0.009612         0.014204 -0.047820
# HasCrCard           1.000000       -0.011866        -0.009933 -0.007138
# IsActiveMember     -0.011866        1.000000        -0.011421 -0.156128
# EstimatedSalary    -0.009933       -0.011421         1.000000  0.012097
# Exited             -0.007138       -0.156128         0.012097  1.000000
# Geography_France    0.002467        0.003317        -0.003332 -0.104955
# Geography_Germany   0.010577       -0.020486         0.010297  0.173488
# Geography_Spain    -0.013480        0.016732        -0.006482 -0.052667
# Gender_Female      -0.005766       -0.022544         0.008112  0.106512
# Gender_Male         0.005766        0.022544        -0.008112 -0.106512
#
#                    Geography_France  Geography_Germany  Geography_Spain  \
# CreditScore               -0.008928           0.005538         0.004780
# Age                       -0.039208           0.046897        -0.001685
# Tenure                    -0.002848          -0.000567         0.003868
# Balance                   -0.231329           0.401110        -0.134892
# NumOfProducts              0.001230          -0.010419         0.009039
# HasCrCard                  0.002467           0.010577        -0.013480
# IsActiveMember             0.003317          -0.020486         0.016732
# EstimatedSalary           -0.003332           0.010297        -0.006482
# Exited                    -0.104955           0.173488        -0.052667
# Geography_France           1.000000          -0.580359        -0.575418
# Geography_Germany         -0.580359           1.000000        -0.332084
# Geography_Spain           -0.575418          -0.332084         1.000000
# Gender_Female             -0.006772           0.024628        -0.016889
# Gender_Male                0.006772          -0.024628         0.016889
#
#                    Gender_Female  Gender_Male
# CreditScore             0.002857    -0.002857
# Age                     0.027544    -0.027544
# Tenure                 -0.014733     0.014733
# Balance                -0.012087     0.012087
# NumOfProducts           0.021859    -0.021859
# HasCrCard              -0.005766     0.005766
# IsActiveMember         -0.022544     0.022544
# EstimatedSalary         0.008112    -0.008112
# Exited                  0.106512    -0.106512
# Geography_France       -0.006772     0.006772
# Geography_Germany       0.024628    -0.024628
# Geography_Spain        -0.016889     0.016889
# Gender_Female           1.000000    -1.000000
# Gender_Male            -1.000000     1.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(corr, annot=True, cmap='summer')
# Out:
# <Axes: >

# %% [markdown]
# # Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
y=df["Exited"]

# %%
x=df.drop("Exited", axis=1)

# %%
x_train,x_test,y_train,y_test= train_test_split( x, y, test_size=0.3, random_state=10, stratify=y)

# %%
# Performing Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
# importing tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, ReLU, Dropout

# %%
cls = Sequential()

# %%
# Adding input layer
cls.add(Dense(units=13, activation="relu"))
# Adding the hidden layer
cls.add(Dense(units=10, activation="relu"))
cls.add(Dropout(0.001))
cls.add(Dense(units=8, activation="relu"))
cls.add(Dropout(0.001))
# Adding the output layer
cls.add(Dense(1,activation="sigmoid"))

# %%
cls.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
early_stopping= tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=20,
    verbose=1,
    mode='auto',
    baseline=None
)

# %%
history = cls.fit(x_train_scaled, y_train, validation_split=0.3, batch_size=40, epochs=500, callbacks=early_stopping)
# Out:
# Epoch 1/500
# 123/123 [==============================] - 2s 5ms/step - loss: 0.5527 - accuracy: 0.7765 - val_loss: 0.4816 - val_accuracy: 0.7938
# Epoch 2/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.8024 - val_loss: 0.4394 - val_accuracy: 0.8057
# Epoch 3/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4291 - accuracy: 0.8118 - val_loss: 0.4291 - val_accuracy: 0.8176
# Epoch 4/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8147 - val_loss: 0.4232 - val_accuracy: 0.8181
# Epoch 5/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8171 - val_loss: 0.4222 - val_accuracy: 0.8238
# Epoch 6/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8247 - val_loss: 0.4159 - val_accuracy: 0.8267
# Epoch 7/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4018 - accuracy: 0.8290 - val_loss: 0.4117 - val_accuracy: 0.8310
# Epoch 8/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8310 - val_loss: 0.4090 - val_accuracy: 0.8343
# Epoch 9/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8345 - val_loss: 0.4037 - val_accuracy: 0.8343
# Epoch 10/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8367 - val_loss: 0.4002 - val_accuracy: 0.8381
# Epoch 11/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3814 - accuracy: 0.8398 - val_loss: 0.3952 - val_accuracy: 0.8390
# Epoch 12/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.8404 - val_loss: 0.3900 - val_accuracy: 0.8438
# Epoch 13/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3718 - accuracy: 0.8422 - val_loss: 0.3861 - val_accuracy: 0.8462
# Epoch 14/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8433 - val_loss: 0.3822 - val_accuracy: 0.8490
# Epoch 15/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8494 - val_loss: 0.3791 - val_accuracy: 0.8490
# Epoch 16/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8496 - val_loss: 0.3802 - val_accuracy: 0.8495
# Epoch 17/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3565 - accuracy: 0.8494 - val_loss: 0.3730 - val_accuracy: 0.8524
# Epoch 18/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3525 - accuracy: 0.8531 - val_loss: 0.3695 - val_accuracy: 0.8500
# Epoch 19/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3510 - accuracy: 0.8506 - val_loss: 0.3672 - val_accuracy: 0.8543
# Epoch 20/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.8539 - val_loss: 0.3657 - val_accuracy: 0.8552
# Epoch 21/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3458 - accuracy: 0.8547 - val_loss: 0.3638 - val_accuracy: 0.8524
# Epoch 22/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3441 - accuracy: 0.8531 - val_loss: 0.3640 - val_accuracy: 0.8571
# Epoch 23/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3428 - accuracy: 0.8547 - val_loss: 0.3604 - val_accuracy: 0.8571
# Epoch 24/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3409 - accuracy: 0.8561 - val_loss: 0.3601 - val_accuracy: 0.8614
# Epoch 25/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3393 - accuracy: 0.8582 - val_loss: 0.3601 - val_accuracy: 0.8605
# Epoch 26/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.8569 - val_loss: 0.3584 - val_accuracy: 0.8571
# Epoch 27/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3378 - accuracy: 0.8571 - val_loss: 0.3575 - val_accuracy: 0.8557
# Epoch 28/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3351 - accuracy: 0.8578 - val_loss: 0.3582 - val_accuracy: 0.8581
# Epoch 29/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3352 - accuracy: 0.8569 - val_loss: 0.3582 - val_accuracy: 0.8638
# Epoch 30/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3331 - accuracy: 0.8584 - val_loss: 0.3567 - val_accuracy: 0.8590
# Epoch 31/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3333 - accuracy: 0.8567 - val_loss: 0.3559 - val_accuracy: 0.8571
# Epoch 32/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3331 - accuracy: 0.8573 - val_loss: 0.3547 - val_accuracy: 0.8614
# Epoch 33/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3307 - accuracy: 0.8610 - val_loss: 0.3561 - val_accuracy: 0.8662
# Epoch 34/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3310 - accuracy: 0.8594 - val_loss: 0.3552 - val_accuracy: 0.8619
# Epoch 35/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3282 - accuracy: 0.8620 - val_loss: 0.3547 - val_accuracy: 0.8600
# Epoch 36/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3284 - accuracy: 0.8598 - val_loss: 0.3570 - val_accuracy: 0.8667
# Epoch 37/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3287 - accuracy: 0.8614 - val_loss: 0.3554 - val_accuracy: 0.8605
# Epoch 38/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3282 - accuracy: 0.8592 - val_loss: 0.3539 - val_accuracy: 0.8652
# Epoch 39/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3271 - accuracy: 0.8594 - val_loss: 0.3534 - val_accuracy: 0.8624
# Epoch 40/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8618 - val_loss: 0.3553 - val_accuracy: 0.8638
# Epoch 41/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.8606 - val_loss: 0.3536 - val_accuracy: 0.8648
# Epoch 42/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3254 - accuracy: 0.8608 - val_loss: 0.3546 - val_accuracy: 0.8676
# Epoch 43/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.8620 - val_loss: 0.3533 - val_accuracy: 0.8652
# Epoch 44/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3253 - accuracy: 0.8639 - val_loss: 0.3548 - val_accuracy: 0.8681
# Epoch 45/500
# 123/123 [==============================] - 0s 4ms/step - loss: 0.3241 - accuracy: 0.8614 - val_loss: 0.3551 - val_accuracy: 0.8590
# Epoch 46/500
# 123/123 [==============================] - 0s 4ms/step - loss: 0.3239 - accuracy: 0.8620 - val_loss: 0.3530 - val_accuracy: 0.8610
# Epoch 47/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3243 - accuracy: 0.8614 - val_loss: 0.3550 - val_accuracy: 0.8619
# Epoch 48/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3229 - accuracy: 0.8604 - val_loss: 0.3542 - val_accuracy: 0.8667
# Epoch 49/500
# 123/123 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.8616 - val_loss: 0.3545 - val_accuracy: 0.8581
# Epoch 50/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3232 - accuracy: 0.8616 - val_loss: 0.3550 - val_accuracy: 0.8619
# Epoch 51/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3211 - accuracy: 0.8622 - val_loss: 0.3542 - val_accuracy: 0.8605
# Epoch 52/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3211 - accuracy: 0.8645 - val_loss: 0.3553 - val_accuracy: 0.8671
# Epoch 53/500
# 123/123 [==============================] - 0s 4ms/step - loss: 0.3210 - accuracy: 0.8641 - val_loss: 0.3546 - val_accuracy: 0.8633
# Epoch 54/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3203 - accuracy: 0.8651 - val_loss: 0.3540 - val_accuracy: 0.8657
# Epoch 55/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3214 - accuracy: 0.8641 - val_loss: 0.3541 - val_accuracy: 0.8633
# Epoch 56/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3213 - accuracy: 0.8616 - val_loss: 0.3548 - val_accuracy: 0.8619
# Epoch 57/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3196 - accuracy: 0.8655 - val_loss: 0.3536 - val_accuracy: 0.8576
# Epoch 58/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3188 - accuracy: 0.8639 - val_loss: 0.3542 - val_accuracy: 0.8681
# Epoch 59/500
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3189 - accuracy: 0.8629 - val_loss: 0.3541 - val_accuracy: 0.8629
# Epoch 59: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
y_log=cls.predict(x_test_scaled)
# Out:
# 94/94 [==============================] - 1s 2ms/step

# %%
import numpy as np
y_pred =np.where(y_log >= 0.5,1,0)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
acc=accuracy_score(y_pred, y_test)
cm=confusion_matrix(y_pred, y_test)

# %%
print("accuracy_score", acc)
# Out:
# accuracy_score 0.8546666666666667

# %%
cm
# Out:
# array([[2262,  309],
#        [ 127,  302]], dtype=int64)

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(cls, open("ann.pkl","wb"))
